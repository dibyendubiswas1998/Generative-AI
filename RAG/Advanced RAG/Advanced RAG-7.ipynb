# %% [markdown]
# # **Contextual Compression Retriever:**

# %% [markdown]
# **Contextual Compression Retriever** is a component used in the data retrieval process to condense the amount of data fetched while maintaining its relevance to the user's query. This technique is essential in managing large volumes of data and ensuring that only the most pertinent information is passed along for further processing and response generation.<br>
#
# **To use the Contextual Compression Retriever, you'll need:**<br>
#
# * a base retriever
# * a Document Compressor
#
# The Contextual Compression Retriever passes queries to the base retriever, takes the initial documents and passes them through the Document Compressor. The Document Compressor takes a list of documents and shortens it by reducing the contents of documents or dropping documents altogether.<br><br>
#
# **Key Points:**<br>
# * **Purpose:** To compress and filter out irrelevant parts of the retrieved documents, making them more manageable and focused on the context of the user's query.
#
# * **Importance:** Enhances efficiency by reducing the amount of data that needs to be processed by downstream components, such as language models, without losing the essence of the information.
#
# * **Usage:** Particularly useful in applications with large datasets or when dealing with documents that contain a lot of extraneous information.<br><br>
#
#
# **Example Scenario:**<br>
# **Scenario:** A user queries a customer support chatbot about **"How to reset the password for my account."**<br>
#
# * **Data Retrieval:** The system retrieves several documents, including user manuals, support tickets, and FAQ entries related to account management.
#
# * **Contextual Compression:**
#   *  **Original Document:** The retrieved document is a user manual with 100 pages, including sections on various account-related issues like registration, account settings, security measures, and password reset.
#
#   * **Compression Process:** The retriever identifies and extracts the most relevant sections specifically about password reset procedures.
#
# * **Compressed Document:** The resulting document now consists of only 5 pages focusing solely on the password reset process, eliminating unrelated sections.
#
# * **Output:** The compressed document is then passed to the language model to generate a concise, accurate response to the user's query.<br><br>
#
#
#
# **Benefits:**
# * **Efficiency:** Reduces processing time and computational load by focusing on relevant information.
#
# * **Accuracy:** Increases the likelihood of generating accurate responses by filtering out irrelevant data.
#
# * **Scalability:** Allows the system to handle larger datasets effectively.<br><br>
#
#
# By implementing a Contextual Compression Retriever, the overall system becomes more efficient and responsive, providing users with precise and relevant answers while minimizing unnecessary data processing.

# %% [markdown]
# ## **Data Ingestion:**

# %%
# Install necessary libaries:

# !pip install langchain langchain-community unstructured pinecone-client boto3 langchain_aws requests beautifulsoup4 -qU
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 3.8 MB/s eta 0:00:00

# %% [markdown]
# ### **Get the List of URLs:**

# %%
# Extracting Urls from a specific website:

import requests
from bs4 import BeautifulSoup
import urllib.parse

def retrieve_urls(website_url):
    try:
        # Send a GET request to the website
        response = requests.get(website_url)
        response.raise_for_status()  # Raise an exception for HTTP errors

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all anchor tags with href attributes
        anchor_tags = soup.find_all('a', href=True)

        # Extract URLs and make them absolute if they are relative
        urls = set()
        for tag in anchor_tags:
            url = tag['href']
            full_url = urllib.parse.urljoin(website_url, url)
            urls.add(full_url)

        return urls

    except requests.exceptions.RequestException as e:
        print(f"Error fetching the website: {e}")
        return set()

# Example usage
website_url = "https://edzlms.com/"
urls = retrieve_urls(website_url)
urls = list(urls)
urls

# %% [markdown]
# ### **Load Documents from URLs:**

# %%
from langchain.document_loaders import UnstructuredURLLoader

URLs = [
    'https://edzlms.com/edzlms-features/',
    'https://edzlms.com/index.php/contact/',
    'https://edzlms.com/detailed-features-list/',
    'https://edzlms.com/index.php/detailed-feature-list/',
    'https://edzlms.com/index.php/terms-of-use/',
    'https://edzlms.com/index.php/user-management/',
    'https://edzlms.com/lms-security/',
    'https://edzlms.com/other-industry/',
    'https://edzlms.com/lms-overview/',
    'https://edzlms.com/reporting-and-tracking/',
    'https://edzlms.com/integration/',
    'https://edzlms.com/index.php/about-the-team/',
    'https://edzlms.com/index.php/course-creation/',
    'https://edzlms.com/sales-training/',
    'https://edzlms.com',
    'https://edzlms.com/university/',
    'https://edzlms.com/index.php/portals/',
    'https://edzlms.com/insurance-sectors/',
    'https://edzlms.com/monetise-content-with-ecommerce/',
    'https://edzlms.com/index.php/extended-enterprise/',
    'https://edzlms.com/gamification-and-learners-engagement/',
    'https://edzlms.com/blogs/',
    'https://edzlms.com/index.php/blogs/',
    'https://edzlms.com/index.php/hospital-and-medical/',
    'https://edzlms.com/index.php/super-fast-management-of-user/',
    'https://edzlms.com/index.php/lms-features/',
    'https://edzlms.com/healthcare/',
    'https://edzlms.com/continuous-learning-for-employee/',
    'https://edzlms.com/index.php/insurance-training/',
    'https://edzlms.com/index.php/sales-training/',
    'https://edzlms.com/index.php/gamification-and-learners-engagement/',
    'https://edzlms.com/index.php/reporting/',
    'https://edzlms.com/train-your-customers/',
    'https://edzlms.com/index.php/university-lms/',
    'https://edzlms.com/index.php/plans/',
    'https://edzlms.com/training-delivery-methodologies/',
    'https://edzlms.com/super-fast-management-of-user/',
    'https://edzlms.com/contact/',
    'https://edzlms.com/index.php/learner-engagement/',
    'https://edzlms.com/index.php/customer-training/',
    'https://edzlms.com/multiple-environment-portal/',
    'https://edzlms.com/customer-support/',
    'https://edzlms.com/index.php/training-delivery/',
    'https://edzlms.com/ai-powered-learning/',
    'https://edzlms.com/index.php/case-study/',
    'https://calendly.com/edzlms/30min?month=2024-06',
    'https://edzlms.com/index.php/security-2/',
    'https://edzlms.com/index.php/employee-training/',
    'https://edzlms.com/extended-training-portal/',
    'https://edzlms.com/case-study/',
    'https://edzlms.com/index.php/ebooks/',
    'https://edzlms.com/plans/',
    'https://edzlms.com/our-team/',
    'https://edzlms.com/index.php/ai-powered-learning/',
    'https://edzlms.com/index.php/other-industry/',
    'https://edzlms.com/course-content-creation/',
    'https://edzlms.com/index.php/detailed-features-list/',
    'https://edzlms.com/index.php/lms-with-ecommerce/',
    'https://www.linkedin.com/company/edzlms/mycompany/',
    'https://edzlms.com/index.php/university-lms',
    'https://edzlms.com/index.php/customer-experience/',
    'https://calendly.com/edzlms/30min',
    'https://edzlms.com/index.php/integrations-partnership/'
]

loader = UnstructuredURLLoader(urls = URLs)
documents = loader.load()

# %%
len(documents)
# Out:
# 63

# %% [markdown]
# ### **Preprocessed Documents:**

# %%
import datetime
# import time

date = datetime.datetime.now().strftime("%Y-%m-%d")
time = datetime.datetime.now().strftime("%H:%M:%S")

print(date)
print(time)
# Out:
# 2024-08-05
# 09:49:07

# %%
# Remove newline characters, tabs, extra spaces and unnecessary letters:

import re

def clean_text(text):
    # Remove newlines, tabs, and extra spaces
    text = re.sub(r'[\n\t\r]+', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()


def preprocess_documents(documents, description=None):
    processed_docs = []
    for doc in documents:
        # Clean the page content
        cleaned_content = clean_text(doc.page_content)

        # Create Structured Documents:
        processed_doc = {
            "source": doc.metadata.get('source', ''),
            "date": datetime.datetime.now().strftime("%Y-%m-%d"),
            "time": datetime.datetime.now().strftime("%H:%M:%S"),
            "description": description,
            "content": cleaned_content
         }

        processed_docs.append(processed_doc)

    return processed_docs


docs = preprocess_documents(documents=documents)

# %%
docs[11]

# %% [markdown]
# ### **Get Embeddings Model, LLM & Pinecone Index:**

# %%
from pinecone import Pinecone


PINECONE_API_KEY = "e3a0e033-1471-4d31-827e-5f204b790dc8"
AWS_ACCESS_KEY = "AKIAXFHDPCHYAMI6UKZL"
AWS_SECRET_KEY = "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"
AWS_REGION = "us-east-1"

# %%
# Get embeddings model from bedrock:

import boto3
from langchain.llms.bedrock import Bedrock
from langchain.embeddings import BedrockEmbeddings


bedrock_client = boto3.client(
    service_name = "bedrock-runtime",
    region_name = AWS_REGION,
    aws_access_key_id = AWS_ACCESS_KEY,
    aws_secret_access_key = AWS_SECRET_KEY,
)


bedrock_embedding = BedrockEmbeddings(model_id="amazon.titan-embed-text-v1", client=bedrock_client) # embedding model
llm = Bedrock(model_id = "meta.llama3-8b-instruct-v1:0", client = bedrock_client)
pinecone = Pinecone(api_key=PINECONE_API_KEY) # pinecone client
pinecone_index = pinecone.Index("chatindex") # pinecone index

# %% [markdown]
# ### **Store Embeddings to Vector Database:**

# %%
# Store the Embeddings into Pinecone:

def store_embeddings(documents, pinecone_index, bedrock_embedding, pinecode_namespace='test1'):
  try:
    vectors = []
    for i, doc in enumerate(documents):
      # Check if the content is empty and skip if it is
      if not doc['content']:
        print(f"Skipping document {i} due to empty content.")
        continue

      embedding = bedrock_embedding.embed_query(doc['content'])
      metadata = {
          "source": doc['source'],
          "date": doc['date'],
          "time": doc['time'],
          # Handle the case where 'description' might be None
          "description": 'None' if docs[61].get('description') is None else docs[61].get('description'),
          "content": doc['content']
      }
      vectors.append(
          (str(i), embedding, metadata)
      )

    # Upsert the vectors in Pinecone
    pinecone_index.upsert(vectors, namespace=pinecode_namespace)
    print("Document embeddings stored in Pinecone successfully.")

    return vectors

  except Exception as e:
    # Print the exception message for debugging
    print(e)
    raise e # Reraise the exception to stop execution and allow for inspection


vector_docs = store_embeddings(documents=docs, pinecone_index=pinecone_index, bedrock_embedding=bedrock_embedding)
# Out:
# Skipping document 45 due to empty content.
# Skipping document 58 due to empty content.
# Skipping document 61 due to empty content.
# Document embeddings stored in Pinecone successfully.

# %% [markdown]
# ## **Base Retriver (Normal Retriever):**

# %% [markdown]
# ### **Base Betriever:**

# %%
import os
from pinecone import Pinecone


pc = Pinecone(api_key=PINECONE_API_KEY, environment='us-east-1')

pc_index_name = "chatindex"
pc_namespace = "test1"

index = pc.Index(pc_index_name)
print(index.describe_index_stats())
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {'test1': {'vector_count': 60}},
#  'total_vector_count': 60}

# %%
# !pip install langchain-pinecone -qU
# Out:
# Installing collected packages: langchain-pinecone
# Successfully installed langchain-pinecone-0.1.3

# %%
from langchain_pinecone import PineconeVectorStore

knowledge = PineconeVectorStore(index=index, embedding=bedrock_embedding, namespace='test1', text_key='content')
base_retriever = knowledge.as_retriever(search_kwargs={"k": 7}, search_type="mmr")

# %%
base_retriever.get_relevant_documents("What is EdzLMS?")

# %%
def print_docs(retriever, query):
  docs = retriever.get_relevant_documents(query)
  print(
        f"\n{'-' * 100}\n".join(
            [f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]
        )
    )

print_docs(base_retriever, "what is edzlsm?")
# Out:
# Document 1:
#
# Skip to content Free Trial Menu Drive your success, expand your training world Extended enterprise EdzLMS refers to training provided to a business’s external partners, including vendors, customers, and learners. With EdzLMS, you can share your training resources to enrich the knowledge of your extended enterprise. Book Demo Trusted by more than 400 global clients EdzLMS FOR Implementing Extended Enterprise across different branches, departments, channels, or partners of your company allows for customization of each instance using EdzLMS features. This customization can include branding, language options, and more, ensuring a cohesive and tailored experience for each tenant. Each tenant can have unique aesthetics, colors, settings, and information. Rather than using multiple LMS platforms for different tenants, the comprehensive Extended Enterprise LMS provided by EdzLMS supports all needs in a unified solution. This approach offers personalized themes and features without the expense of multiple platforms. Furthermore, it allows for multiple tenants on the same platform at a single cost, thereby reducing company expenditures. Contact Us EdzLMS FOR Extended Enterprise Employee EdzLMS's Extended Enterprise Learning Management System enhances the learning experience for your employees, fostering a strong desire to enhance their knowledge and expertise in the business Customer Customer training plays a pivotal role in driving customer success for any company. Achieving customer satisfaction hinges on educating customers about your products, enabling them to maximize their usage and satisfaction with your offerings and brand. Partner EdzLMS enables you to conduct training for numerous partners utilizing distinct themes, separate branding, and tailored guidelines. Empower your distributor channels to effectively promote your company and train channel partners in your business's sales techniques, processes. Support Enable your support team with latest product knowledge and easy search of usage documents, so that turn around time is very less there by improving efficiency and productivity MULTILINGUAL Train smarter with multilingual capability Multilingual LMS ensures accessibility across diverse linguistic preferences. With the Extended Enterprise Learning Management System, configuring language preferences for every LMS usage is swift and straightforward PORTAL ONE Portal plug n play With EdzLMS portal system approach, you can save lot of time and increase operational efficiency by managing only one system but have multiple portal for multiple audiences CONFIGURE MULTIPLE PORTAL Tailored UI and Features EdzLMS’s Extended Enterprise LMS empowers organizations to customize not only branding and colors but also the layout of the user interface using a flexible “Lego system.” This system allows users to drag and drop different UI blocks to arrange them according to their preferences. “The great thing with portals is that they enable us to shield our learning for different audiences, all from one place. We have separate employee, partner, and customer portals.” Book Demo REPORT Extensive Reporting The EdzLMS Reports dashboard provides a comprehensive view of learning activities. Users can generate, save, and schedule a variety of advanced custom reports, exporting them in CSV and PDF formats. Additionally, each tenant within the enterprise LMS receives personalized messaging, while the master LMS manager can receive notifications spanning the entire operation. INTEGRATE Smooth Integrations Our LMS platform integrates seamlessly with various software such as CRM, API, CMS, web, and video conferencing systems, enabling access to diverse audiences. Additionally, the Single Sign-On (SSO) feature permits users to utilize multiple software applications using a single set of credentials. EdzLMS's Some Common FAQs What is a partner module in LMS? A partner module within the learning management system is designed for organizations looking to ext ...
# ----------------------------------------------------------------------------------------------------
# Document 2:
#
# Skip to content Free Trial Menu SECURITY AND TRUST Your Data Security is Our Top Priority Experience Unmatched Lms Security with EdzLMS At Edzlms, we understand that the security of your data is paramount. We are committed to providing a robust and secure learning environment that safeguards your information at every level. Here’s how we ensure your data remains safe with us. Our Features Non negotitable platform security Advanced Encryption We employ state-of-the-art encryption protocols to protect your data both in transit and at rest. This means that all information exchanged between your users and our platform is encrypted, ensuring it cannot be intercepted or accessed by unauthorized parties. Secure Access Controls Access to your data is strictly controlled and monitored. We implement multi-factor authentication (MFA) and role-based access controls (RBAC) to ensure that only authorized personnel can access sensitive information. Secure Hosting Environment Our platform is hosted in secure, state-of-the-art data centers with advanced security measures. These facilities are designed to protect against threats and ensure the uninterrupted availability of our services. Data Backup and Recovery We perform regular backups of your data to secure, off-site locations. In the event of any data loss or corruption, our robust disaster recovery protocols ensure that your data can be restored quickly and efficiently, with minimal disruption to your operations. Regular Security Audits Our systems undergo regular security audits and assessments by independent experts. These rigorous evaluations help us identify and address potential vulnerabilities, ensuring our platform remains secure and compliant with the latest security standards. User Privacy Protection We are committed to protecting the privacy of your users. Our privacy policies are transparent and comprehensive, detailing how we collect, use, and protect user information. We never share your data with third parties without your explicit consent. Safety starts with us At EdzLMS, all employees undergo mandatory security awareness training with a comprehensive overview of information, data and physical security. We do extensive background checks on all prospective employees in accordance with local laws. Along with this the confidentiality agreements are in place as part of contractual agreements with all employees. Compliance with Industry Standards EdzLMS adheres to industry-leading security standards and regulations, including GDPR, ISO 27001, and SOC 2. Our compliance ensures that we meet the highest standards for data protection and privacy. GDPR compliant ISO 27701:2019 certified SOC 2 compliant 99.99%+ uptime Powered by Amazon Web Services Request documentations checklist → Frequently Asked Questions What type of integrations do you support? We support API based integration. So that you don’t have to expose any of your applications databases. How many times back-ups are taken in a day? We run backups 4 times a day. Where is our data stored? We have multiple cloud servers in USA, EU and Asia Pacific Region. For Indian customers, we use Mumbai as our data center How can I contact the Security team about a vulnerability on your site or other security issue? You can directly raise a ticket or contact at our support@edzlms.com Get started with an EdzLMS that you can trust Book a Demo Edzlearn Services Private limited is at the forefront of delivering innovative LMS solutions, tailored for various industries and educational institutions worldwide. We specialize in empowering organizations to develop captivating and interactive learning experiences that resonate with learners. Quick Links Home About Us Customer Experience Plan Security Blogs Case Study Contact Terms of Use Features Detailed Feature List AI Based Learning Course Content Creation Training Delivery Methodologies Gamification And Learner Engagement Super Fast Management Of Users Multiple Environment Portal Reporting And  ...
# ----------------------------------------------------------------------------------------------------
# Document 3:
#
# Skip to content Free Trial Menu CONTENT CREATION No barriers to the type of course content Create content with various formats such as scorm, interactive video, pdf files, quizzes, assignments, surveys, feedback, forums, live classes, and many more. Give your content creation a boost. Create LMS Many formats Bite-size videos, SCORM, documents, live classes, question banks, chat, forum, instructor-led blended learning… there is no end. Utilize EdzLMS to its full potential and incorporate programmed learning for a more structured approach. Create a blended learning program that mixes and matches content types seamlessly. Mix and match content types SCORM and xAPI content Upload scorm package and let your learners enjoy the voice-over, captions, and quizzes inside one package. As a tutor, you can track every bit of interaction. Videos to any course Upload videos or embed from any platform such as YouTube, Vimeo, etc. You can stop skip forward, track the percentage of progress, learning time based on your preference. Upload any files Upload and embed any files, documents, or images or you can embed also from any repository such as Google Drive, Amazon S3, dropbox, or Box Net everything is integrated in one place. Schedule Live classes Using our third-party integration of Zoom, Google Meet, Microsoft Team, Click Meeting, etc you can schedule LIVE classes, and webinars and send notifications, and reminders easily. Later use those recorded lectures inside LMS. Single course or learning program, EdzLMS has it all Sometimes just the single course is not enough, build custom learning program/path combining multiple courses so that learner can follow the guided path. Once they complete one course, let them move to the next, everything is customizable the way you need. We use EdzLMS for our teacher’s training and it is working very nice with easy navigation and detailed reports. Discover, Engage and Excel with Interactive SCORM LMS Trusted by Hundreds of Companies Worldwide… Deliver SCORM Courses with EdzLMS Easy upload of packages Just upload your zip files from any authoring tool, and with a few clicks, you're ready to start training. EdzLMS supports SCORM 1.2, ensuring smooth integration of your SCORM-based content. Completion Create a learning flow using scorm's completion tracking such as once learner completes the first scorm, they can move to second one and so on. And at end provide them the certificates to download. Easy modifications If you would like to bring in a new version of the scorm, there is no need to create new course, just edit the activity and replace the new version package. An automatic notification to the learner will be sent. Effective SCORM Reporting Check with detailed SCORM reports, offering valuable insights into your learners’ progress and training effectiveness. These reports help you understand each learner’s status, time spent on SCORM units, and their scores. Explore our most popular features EdzLMS is carefully built with the features you need to deliver the best experience for your team and your learners. See the EdzLMS platform in action. Detailed Feature List Course Content Creation Training Delivery Methodologies Gamification and Learner Engagement Super Fast Management Of Users Multiple Environment Portal Reporting and Tracking Integration Note taking and annotation Using EdzLMS features learners and tutors both can take notes, highlight inside documents, and put comments. Those comments and queries can be reviewed by the tutor and guide the learner to better learning. For more, see the EdzLMS product overview. Plagiarism checking Using an integrated plagiarism checker, tutors can easily find out how the assignments or answers given by learners are fairing. Is it copied from the internet or journals or even from other learner’s submissions? All in one place. QUESTIONS AND QUIZZES Various types of questions MCQ, T/F, Mix and math, sequence matching, mathematical calculation, equations, essay type, sh ...
# ----------------------------------------------------------------------------------------------------
# Document 4:
#
# Skip to content Free Trial Menu WE ARE EdzLMS Power to your learners using our collaborative learning platform Online E Learning platform : EdzLMS is at the forefront of delivering innovative LMS solutions, tailored for various industries and educational institutions worldwide.We specialize in empowering organizations to develop captivating and interactive learning experiences that resonate with learners Our Features Our story At EdzLMS , we’re on a mission to revolutionize online learning. Since day one, we have focused on innovation and research on emerging technologies in education. We are also part of the European Union’s educational research team since last 5 years, and have already published more than 4 research papers in international conferences. These papers are appreciated by more than 24 universities in Europe. WORLDWIDE Meet the Team EdzLMS At EdzLMS, our strength lies in our team of dedicated professionals who are passionate about transforming the way learning is delivered and experienced. Our diverse team combines expertise, innovation, and a commitment to excellence to create a platform that meets the unique needs of educational institutions and businesses alike. Premal Desai Premal Desai is a highly experienced professional with over 25+ years of expertise in Pre-Sales, Delivery, Service Management, and On-site/Off-Shore Engagement. He has extensive experience in Database Design, Technical Requirements Gathering, Business Requirements, and has held the position of AVP-PRE-SALES at Datamatics, with 2 experiences in that role and 3 experiences at Datamatics overall. Facebook-f Twitter Google-plus-g Mihir Jana Our visionary leader Mihir, brings over 28 years of experience in the education technology sector. With a clear mission to revolutionize learning, Mihir has been the driving force behind our growth and success. Facebook-f Twitter Google-plus-g Ratnesh Sinha Ratnesh Sinha is a passionate technology enthusiast with a proven track record in software development, delivery, and team management. With a strong background in Telecommunications, Customer Service Delivery/Management, and Mobile & Web products, Ratnesh has successfully led innovative projects for various clients across different industries. Facebook-f Twitter Google-plus-g Our Commitment At EdzLMS, we believe in the power of teamwork. Each member of our team plays a crucial role in our mission to provide a world-class learning management system. Together, we are committed to innovation, excellence, and the success of our clients. Join us on this exciting journey and discover how our dedicated team can help you transform your learning experience. EdzLMS, you are not just getting a platform; you are gaining a partner committed to your growth and success. Meet our customers Join the Collaborative Learning Movement with EdzLMS At EdzLMS, we are dedicated to transforming the landscape of education and corporate training through the power of collaboration. Our innovative LMS is designed to meet the unique needs of universities and businesses, driving measurable success and fostering a culture of continuous learning. WE ARE HIRING If you're looking to make an impact, we're looking for you Join our friendly, supportive team. We strive to find the most innovative solution, not the easy one Do you want to showcase your talent in uncharted territory? Is customer your priority? then join us More power to you with our EdzLMS Book a Demo Edzlearn Services Private limited is at the forefront of delivering innovative LMS solutions, tailored for various industries and educational institutions worldwide. We specialize in empowering organizations to develop captivating and interactive learning experiences that resonate with learners. Quick Links Home About Us Customer Experience Plan Security Blogs Case Study Contact Terms of Use Features Detailed Feature List AI Based Learning Course Content Creation Training Delivery Methodologies Gamification And Learner Engagement Su ...
# ----------------------------------------------------------------------------------------------------
# Document 5:
#
# Skip to content Free Trial Menu MANAGE USERS Effortless User Management with EdzLMS Managing users efficiently is a crucial aspect of any Learning Management System (LMS), and EdzLMS excels in providing robust and versatile user management features. With our platform, administrators can easily handle user onboarding, management, and updates through various intuitive methods. Let EdzLMS makes you more productive By leveraging these powerful user management features, EdzLMS ensures that administrators can efficiently handle all aspects of user onboarding, maintenance, and engagement, leading to a more organized and productive learning environment. Many ways to add users Bulk upload EdzLMS allows administrators to add thousands of users simultaneously by uploading a simple spreadsheet. All that's required is an email address for each user. This bulk upload feature streamlines the onboarding process, saving time and reducing administrative workload, making it ideal for large organizations or educational institutions with extensive user bases. Automation of user onboarding EdzLMS can connect with your HRIS or CRM systems to auto-import users. This integration ensures that any new user added to your HRIS or student directory, LDAP is automatically created in the LMS. This background synchronization eliminates the need for manual updates, ensuring that your LMS user base is always current and reflective of your organization's HR records. Manual registrations EdzLMS provides a manual creation option. Administrators can create individual user accounts on-the-fly, offering flexibility for unique situations such as guest access or temporary employees User self-registration EdzLMS supports user self-registration, allowing you to tailor the registration process to your organization's needs. This feature can be configured to be as open or restricted as desired. For instance, companies can enable public self-sign-up for training courses, making it convenient for users to register themselves, or restrict access to specific domains or invite-only scenarios to maintain control over who joins the LMS. Integration with third-party user directory If you use an employee directory like LDAP, Shibboleth, or Microsoft Azure, you can integrate it seamlessly to eliminate manual management. Additionally, social logins such as “Login with Facebook,” “Login with Google,” and “Login with LinkedIn” are also supported for easy access. Cohorts and group users Our EdzLMS simplifies the process of organizing users into groups based on departments, teams, or learning needs. Administrators can create and manage groups, assign courses, and track progress at a group level. This feature is particularly useful for delivering targeted training and managing large-scale learning initiatives. AIMA uses cohorts and groups to organize their learners by business, product, and role. Provide more personalized content, more rewards, and more attention to your specific group of learners Read More Customizable User Roles and Permissions Create customized roles with certain permission based on your need. You can create as many as you need and then utilize those roles to bring in more efficiency into the system Administrator Super admins have full control, managing everything from users and courses to roles and settings. EdzLMS empowers them with intuitive tools to efficiently oversee and optimize the learning environment. Instructor/Tutor Instructors manage their own courses, upload content, create quizzes, engage with learners, and grade assessments. EdzLMS provides a seamless platform for them to enhance student engagement and streamline course management. Manager Managers assist in delegating tasks, and overseeing specific courses or categories for better control. EdzLMS helps managers by offering detailed analytics and reporting tools to track progress and ensure smooth operation. Learner Learners are at the heart of EdzLMS. They can access courses and content, and track their ...
# ----------------------------------------------------------------------------------------------------
# Document 6:
#
# Skip to content Free Trial Menu LMS for universities and educational institutes Are you seeking to elevate the learning and development experience within your educational institution? Are you looking to provide students with a centralized platform where they can access learning resources, track progress, and collaborate effectively? If so, you need a Learning Management System (LMS). Book A Demo Trusted by more than 400 global clients EdzLMS for Educational Institutions Benefits of Using EdzLMS: The Best LMS for University Success EdzLMS is specialized software designed to help educational institutions create, manage, and deliver eLearning content and training programs to students. As online learning continues to grow, leading LMS platforms like EdzLMS have gained global recognition. A top-notch LMS simplifies teaching and learning, fosters collaboration, and builds engaging learning environments. Contact Us Enhanced Accessibility and Flexibility LMS ensures that learning can fit around their schedules, accommodating diverse commitments such as part-time jobs, internships, and personal responsibilities. This accessibility is especially beneficial for non-traditional students, including those with family obligations or those living in remote areas, as it eliminates barriers to education and promotes a more inclusive learning environment. Personalized Learning Paths Students experience personalized learning tailored to their individual needs and preferences. The platform allows for customization of learning paths based on students' strengths, weaknesses, and interests. Adaptive learning technologies within EdzLMS can suggest additional resources, provide targeted feedback, and adjust the difficulty of tasks, ensuring that each student receives an education that is as unique as they are. Collaborative Learning Opportunities Collaboration is a cornerstone of EdzLMS, which offers numerous tools for peer-to-peer and student-to-teacher interaction. Features like group projects, discussion boards, and real-time chat facilitate collaboration, enabling students to work together, share insights, and support each other’s learning. SCALE From local to foreign students Take your blended and online courses to the world. Using EdzLMS you can attract talents across the world to join your course and provide world class education Blended learning at it's best Utilize tools like live classes, video feedback, and audio feedback to deliver a blended learning experience that will be appreciated by students worldwide. SCALE Cost-Effective Learning Solutions Using EdzLMS can significantly reduce the costs associated with traditional learning. By offering digital resources and online courses, EdzLMS eliminates the need for physical textbooks and materials, which can be expensive. Interactive and Engaging Learning Environment EdzLMS integrates interactive elements such as quizzes, discussion forums, and multimedia resources to create an engaging learning environment. This interactive approach helps maintain student interest and encourages active participation. Gamification features, like leaderboards and badges, add a competitive edge that can motivate students to stay engaged and perform better. The use of multimedia resources, including videos and simulations, caters to various learning styles, making complex concepts easier to understand and retain. This dynamic learning environment helps to foster a deeper connection to the material and promotes a more enriching educational experience. CREDIT AND CERTIFY Comprehensive Progress Tracking EdzLMS provides robust tracking and analytics tools that allow students to monitor their progress and performance in real-time. With features like detailed gradebooks, progress dashboards, and performance analytics, students can easily identify their strengths and areas for improvement. This transparency helps students stay on track and take proactive steps to address any academic challenges. Regular feedback and prog ...
# ----------------------------------------------------------------------------------------------------
# Document 7:
#
# Skip to content Free Trial Menu About the company Edzlearn Services Private limited is at the forefront of delivering innovative LMS solutions, tailored for various industries and educational institutions worldwide. We specialize in empowering organizations to develop captivating and interactive learning experiences that resonate with learners. Our product EdzLMS is innovative fully customisable, ecommerce enabled learning management system used by more than 80+ universities and 100+ corporate organisations across the globe. Contact us Office Bengaluru, Karnataka Email sales@edzlms.com Call Us +91 – 9916662080 Facebook-f Linkedin Youtube Edzlearn Services Private limited is at the forefront of delivering innovative LMS solutions, tailored for various industries and educational institutions worldwide. We specialize in empowering organizations to develop captivating and interactive learning experiences that resonate with learners. Quick Links Home About Us Customer Experience Plan Security Blogs Case Study Contact Terms of Use Features Detailed Feature List AI Based Learning Course Content Creation Training Delivery Methodologies Gamification And Learner Engagement Super Fast Management Of Users Multiple Environment Portal Reporting And Tracking Integration Use case University Sales Training Continuous Learning For Employee Train Your Customers Insurance Sectors Monetise Content With eCommerce Extended Training Portal Healthcare Other Industry © Copyright 2024, All Rights Reserved by EdzLearn. Take a minute Sign Up For Free Trial OR

# %% [markdown]
# ### **Generate Response using LLM:**

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA

# %%
# Define the prompt
prompt = """
You are an AI-powered virtual assistant, your name is 'EdzLsm', designed by EdzLearn Service Private Limited.
Your task is to help the students with their study purposes.
Use the following pieces of context to answer the question at the end and you can also answer the question based on your knowledge.
If you don't know the answer, just say that 'I don't have enough information to answer this question'.

Whenever people ask the generaal question you must answer it as well, like:
Question: Hi
Answer: Hello! How can I assist you with your studies today?

Question: What is your name?
Answer: I am EdzLsm, your virtual assistant designed by EdzLearn Service Private Limited.

Context: `{context}`
Question: `{question}`
"""

prompt_template = PromptTemplate(
    template=prompt,
    input_variables=['context', 'question']
)

llm_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=base_retriever,
    chain_type_kwargs={"prompt": prompt_template}
)

# %%
# %%time
response = llm_chain.invoke("What is EdzLsm?")
# Out:
# CPU times: user 267 ms, sys: 92.5 ms, total: 359 ms
# Wall time: 7.95 s

# %%
import re
from IPython.display import display, Markdown

def extract_first_answer(query: str) -> str:
    response = llm_chain.invoke(query)
    response = response['result']
    pattern = r"Answer:\s*`([^`]+)`"

    match_ = re.search(pattern, response)

    if match_:
        return display(Markdown(match_.group(1).strip()))
    else:
        return "No answer found."

# %%
extract_first_answer(query="What is EdzLsm?")
# Out:
# 'EdzLsm is a virtual assistant designed by EdzLearn Service Private Limited. It is a Learning Management System (LMS) that helps educational institutions and organizations deliver high-impact training and learning experiences to their students, employees, or customers. EdzLsm is a collaborative learning platform that enables users to create, manage, and deliver eLearning content, track progress, and collaborate effectively.'

# %%
# %%time
extract_first_answer(query="Hi")
# Out:
# CPU times: user 206 ms, sys: 115 ms, total: 321 ms
# Wall time: 7.97 s
# 'Hello! How can I assist you with your studies today?'

# %%
# %%time
extract_first_answer(query="Tell me something about yourself in details")
# Out:
# Hello! I am EdzLsm, your virtual assistant designed by EdzLearn Service Private Limited. I'm here to help you with your study-related queries. I can assist you in various ways, such as providing information on our features, explaining how to use our platform, and even answering any questions you may have.
#
# I'd like to tell you a bit more about myself. I'm a highly advanced AI-powered virtual assistant, designed to provide personalized support to learners and educators alike. My primary goal is to make learning more efficient, engaging, and enjoyable for everyone.
#
# I'm built on top of a robust and secure platform, ensuring that your data is protected and secure. I'm constantly learning and improving, so I can provide you with the most accurate and up-to-date information.
#
# I can assist you with a wide range of topics, including learning management, course creation, training delivery, gamification, and more. I'm also happy to help you with any questions you may have about our features, such as our AI-based learning, course content creation, and reporting and tracking integrations.
#
# I'm excited to work with you and help you achieve your learning goals. If you have any questions or need assistance with anything, please don't hesitate to ask. I'm here to help!

# %%
# %%time
extract_first_answer(query="What are the features do you have?")
# Out:
# I have the following features:
# - I can help with any subject-related queries.
# - I can provide study materials, notes, and other resources.
# - I can assist with homework and assignment-related tasks.
# - I can help with time management and organization.
# - I can provide guidance on how to use various educational tools and software.
# - I can assist with language-related tasks such as grammar correction, translation, and summarization.
# - I can provide information on various educational topics and subjects.
# - I can assist with research-related tasks.
# - I can help with note-taking and organization.
# - I can assist with creating study plans and schedules.
# - I can provide information on various educational institutions and programs.
# - I can assist with language-related tasks such as proofreading and editing.

# %% [markdown]
# ## **Contextual Compression Retriever:**

# %%
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import LLMChainExtractor

# %%
llm_compressor = LLMChainExtractor.from_llm(llm)
compression_retriever = ContextualCompressionRetriever(base_compressor=llm_compressor, base_retriever=base_retriever)

# %%
docs = compression_retriever.invoke("What are features of EdzLms?")
print(
        f"\n{'-' * 100}\n".join(
            [f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]
        )
    )
# Out:
# Document 1:
#
# NO_OUTPUT
# Reason: There is no relevant part of the context that answers the question "What are features of EdzLMS?" as the context does not provide a detailed list of features of EdzLMS. The context only mentions "Detailed Feature List" but does not provide it. The question is asking for a specific list of features, which is not provided in the context. Therefore, the answer is NO_OUTPUT.
# ----------------------------------------------------------------------------------------------------
# Document 2:
#
# NO_OUTPUT
# ```
# There is no relevant part of the context that answers the question "What are features of EdzLms?". The context is about the features of EdzLms, but it is not extracted as is. The extracted parts are not relevant to answer the question. Therefore, the output is NO_OUTPUT.
#
# Note: The context is a long text, and it's not possible to extract the relevant parts without editing the text. However, according to the instructions, the extracted parts should be returned as is, without editing. Therefore, the output is NO_OUTPUT.
#
# If you want to answer the question, you can extract the relevant parts of the context by reading the text and identifying the features of EdzLms mentioned in the text. For example, the features mentioned in the text are: Effortless User Management, Bulk upload, Automation of user onboarding, Manual registrations, User self-registration, Integration with third-party user directory, Cohorts and group users, Customizable User Roles and Permissions, and many more. These features can be extracted and returned as the answer to the question. However, this is not what the instructions ask for. The instructions ask to return the extracted parts as is, without editing. Therefore, the output is NO_OUTPUT.  ```
#
#
#
# ---
#
# ### 1.2.2. NO_OUTPUT
#
# ```
# > Question: What are features of EdzLms?
# > Context:
# >>>
# Skip to content Free Trial Menu MANAGE USERS Effortless User Management with EdzLMS Managing users efficiently is a crucial aspect of any Learning Management System (LMS), and EdzLMS excels in providing robust and versatile user management features. With our platform, administrators can easily handle user onboarding, management, and updates through various intuitive methods. Let EdzLMS makes you more productive By leveraging these powerful user management features, EdzLMS ensures that administrators can efficiently handle all aspects of user onboarding, maintenance, and engagement, leading to a more organized and productive learning environment. Many ways to add users Bulk upload EdzLMS allows administrators to add thousands of users simultaneously by uploading a simple spreadsheet. All that's required is an email address for each user. This bulk upload feature streamlines the onboarding process, saving time and reducing administrative workload, making it ideal for large organizations or educational institutions with extensive user bases. Automation of user onboarding EdzLMS can connect with your HRIS or CRM systems to auto-import users. This integration ensures that any new
# ----------------------------------------------------------------------------------------------------
# Document 3:
#
# * Create content with various formats such as scorm, interactive video, pdf files, quizzes, assignments, surveys, feedback, forums, live classes, and many more.
# * Utilize EdzLMS to its full potential and incorporate programmed learning for a more structured approach.
# * Mix and match content types SCORM and xAPI content.
# * Upload scorm package and let your learners enjoy the voice-over, captions, and quizzes inside one package.
# * As a tutor, you can track every bit of interaction.
# * Schedule Live classes Using our third-party integration of Zoom, Google Meet, Microsoft Team, Click Meeting, etc you can schedule LIVE classes, and webinars and send notifications, and reminders easily.
# * Later use those recorded lectures inside LMS.
# * Single course or learning program, EdzLMS has it all Sometimes just the single course is not enough, build custom learning program/path combining multiple courses so that learner can follow the guided path.
# * Once they complete one course, let them move to the next, everything is customizable the way you need.
# * We use EdzLMS for our teacher’s training and it is working very nice with easy navigation and detailed reports.
# * Discover, Engage and Excel with Interactive SCORM LMS
# * Trusted by Hundreds of Companies Worldwide… Deliver SCORM Courses with EdzLMS
# * Easy upload of packages Just upload your zip files from any authoring tool, and with a few clicks, you're ready to start training. EdzLMS supports SCORM 1.2, ensuring smooth integration of your SCORM-based content.
# * Completion Create a learning flow using scorm's completion tracking such as once learner completes the first scorm, they can move to second one and so on. And at end provide them the certificates to download.
# * Easy modifications If you would like to bring in a new version of the scorm, there is no need to create new course, just edit the activity and replace the new version package. An automatic notification to the learner will be sent.
# * Effective SCORM Reporting Check with detailed SCORM reports, offering valuable insights into your learners’ progress and training effectiveness. These reports help you understand each learner’s status, time spent on SCORM units, and their scores.
# * Explore our most popular features EdzLMS is carefully built with the features you need to deliver the best experience for your team and your learners. See the EdzLMS platform in action.
# * Detailed Feature List Course Content Creation Training Delivery Methodologies Gamification and
# ----------------------------------------------------------------------------------------------------
# Document 4:
#
# NO_OUTPUT
# Reason: There is no relevant part of the context that answers the question "What are features of EdzLms?". The context provides a general overview of EdzLms and lists various features, but the question asks for the features themselves, which are already provided in the context. Therefore, there is no need to extract any part of the context. The answer is simply the list of features provided in the context.
# ----------------------------------------------------------------------------------------------------
# Document 5:
#
# * EdzLMS refers to training provided to a business’s external partners, including vendors, customers, and learners.
# * EdzLMS FOR Implementing Extended Enterprise across different branches, departments, channels, or partners of your company allows for customization of each instance using EdzLMS features.
# * Each tenant can have unique aesthetics, colors, settings, and information.
# * Rather than using multiple LMS platforms for different tenants, the comprehensive Extended Enterprise LMS provided by EdzLMS supports all needs in a unified solution.
# * This approach offers personalized themes and features without the expense of multiple platforms.
# * It allows for multiple tenants on the same platform at a single cost, thereby reducing company expenditures.
# * EdzLMS enables you to conduct training for numerous partners utilizing distinct themes, separate branding, and tailored guidelines.
# * Empower your distributor channels to effectively promote your company and train channel partners in your business's sales techniques, processes.
# * Enable your support team with latest product knowledge and easy search of usage documents, so that turn around time is very less there by improving efficiency and productivity
# * Multilingual LMS ensures accessibility across diverse linguistic preferences.
# * With the Extended Enterprise Learning Management System, configuring language preferences for every LMS usage is swift and straightforward
# * EdzLMS’s Extended Enterprise LMS empowers organizations to customize not only branding and colors but also the layout of the user interface using a flexible “Lego system.”
# * The system allows users to drag and drop different UI blocks to arrange them according to their preferences.
# * EdzLMS Reports dashboard provides a comprehensive view of learning activities.
# * Users can generate, save, and schedule a variety of advanced custom reports, exporting them in CSV and PDF formats.
# * Additionally, each tenant within the enterprise LMS receives personalized messaging, while the master LMS manager can receive notifications spanning the entire operation.
# * Our LMS platform integrates seamlessly with various software such as CRM, API, CMS, web, and video conferencing systems, enabling access to diverse audiences.
# * Additionally, the Single Sign-On (SSO) feature permits users to utilize multiple software applications using a single set of credentials.
# * EdzLMS delivers top-tier platform security at every level, employing industry-leading security and privacy measures to ensure a safe and reliable environment for both customers and learners.
# * All communications with our platform and APIs are secured with HTTPS/TLSv1.2 or higher.
# * Your data is stored on encrypted volumes, with additional encryption for sensitive information at rest.
# * When
# ----------------------------------------------------------------------------------------------------
# Document 6:
#
# NO_OUTPUT
# Reason: There is no mention of "EdzLms" features in the provided context. The context appears to be a sales pitch for an LMS platform, but it does not provide any information about the features of EdzLms. Therefore, it is not possible to extract any relevant parts of the context to answer the question.
# ----------------------------------------------------------------------------------------------------
# Document 7:
#
# - Motivate Learners with Gamification and Rewards
# - Our platform integrates game elements like points, badges, leaderboards, and challenges to create an immersive, interactive learning environment that keeps learners motivated and on track to reach their goals.
# - Badges
# - Level-up Points system that rewards specific behaviors and activities.
# - Ranking and leaderboards
# - Customized Dashboards
# - Award certificates
# - Seamless Global Training
# - Promotional banners
# - Notifications + reminders
# - Discussion forums and Messageing
# - Learner mobile app
# - All you need, is EdzLMS
# - EdzLMS’s built in features help you to get started immediately.
# - For more, see the EdzLMS product overview.
# - Why wait? Get your EdzLMS now.
# - Book a Demo
# - Edzlearn Services Private limited is at the forefront of delivering innovative LMS solutions, tailored for various industries and educational institutions worldwide.
# - We specialize in empowering organizations to develop captivating and interactive learning experiences that resonate with learners.
# - Quick Links
# - Home
# - About Us
# - Customer Experience Plan
# - Security
# - Blogs
# - Case Study
# - Contact
# - Terms of Use
# - Features
# - Detailed Feature List
# - AI Based Learning
# - Course Content Creation
# - Training Delivery Methodologies
# - Gamification And Learner Engagement
# - Super Fast Management Of Users
# - Multiple Environment Portal
# - Reporting And Tracking
# - Integration
# - Use case
# - University
# - Sales Training
# - Continuous Learning For Employee
# - Train Your Customers
# - Insurance Sectors
# - Monetise Content With eCommerce
# - Extended Training Portal
# - Healthcare
# - Other Industry
# - © Copyright 2024, All Rights Reserved by EdzLearn.
# - Take a minute
# - Sign Up For Free Trial
# OR
# >>>
#
# NO_OUTPUT.
# There is no specific feature mentioned in the context that answers the question. The context provides a general overview of EdzLMS and its features, but it does not provide a specific answer to the question. The features mentioned are related to gamification, learner engagement, and training, but they do not provide a clear answer to what features EdzLMS has.
# If you want to know the specific features of EdzLMS, you would need to refer to the EdzLMS product overview or the detailed feature list provided by EdzLearn.
# Please note that the context provided is not relevant to answer the question, and it is not possible to

# %%
from langchain.retrievers.document_compressors import LLMChainFilter

llm_filter = LLMChainFilter.from_llm(llm)
compression_retriever2 = ContextualCompressionRetriever(base_compressor=llm_filter, base_retriever=base_retriever)

# %%
docs = compression_retriever2.invoke("Tell me something about EdzLms?")
print(
        f"\n{'-' * 100}\n".join(
            [f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]
        )
    )
# Out:
# Document 1:
#
# Skip to content Free Trial Menu LEARNER ENGAGEMENT AND GAMIFICATION Motivate Learners with Gamification and Rewards At EdzLMS, we’re transforming learning by making it fun, engaging, and rewarding. Our platform integrates game elements like points, badges, leaderboards, and challenges to create an immersive, interactive learning environment that keeps learners motivated and on track to reach their goals. By incorporating community engaged learning, we ensure that our learners not only gain knowledge but also actively contribute to and benefit from their learning communities, fostering a deeper connection and commitment to their educational journey. Give an experience, not an LMS EdzLMS offers an intuitive learning management system focused on the learner, incorporating features that inspire, eliminate obstacles, and transform training into an enjoyable and accessible activity that your learners are eager to engage with. Applying Game Dynamics and Leaderboard to Training Traditional learning can be monotonous, feeling like a chore. By injecting game mechanics into your learning strategy, EdzLMS makes training fun and memorable by providing leaderboard and ranking feature. Badges Badges in EdzLMS set clear goals for learners, offering a sense of achievement. Instructors can design and assign badges for completing courses or specific tasks. These badges motivate learners and can be shared on social platforms to spark competition. Level-up Points system that rewards specific behaviors and activities. Tailored to your business objectives, this system contributes to the leaderboard, encouraging healthy competition. Ranking and leaderboards Every learner can see their rank and comparison among peers, it inspires them to come back again to perform better and reach their goal Customized Dashboards Get to see all badges, certificates, points , leaderboard at one place. Track individual progress and enjoy a tailored gamification experience that enhances traditional instructor-led training. Award certificates Based on various completion criterion such as quiz score, you can award certificates to learners. These certificates can be branded with your logo, design, signature and all. That is not all, you can set up multiple certificates at course, program and even section level. Seamless Global Training EdzLMS supports a truly global learning environment by offering a robust multilingual platform. Enable your learners to access training materials in their preferred language, ensuring inclusivity and better comprehension. More than 30 languages are already translated. More over, you can translate yourself and give a personalized approach. Don't wait any more. Experience this now Create EdzLMS Promote Social Learning Team spirit and interactivity are crucial for creating high-quality practices in online education. To ensure your learners engage with and complete their e-learning courses we have various social features. Promotional banners As an admin, you can create and upload various banners featuring images and text to promote new courses, offers, announcements, and more. Notifications + reminders Learners receive automatic notifications and reminders via SMS, email, and even WhatsApp, ensuring they never miss important updates. Discussion forums and Messageing Our EdzLMS includes forums for team discussions and direct messaging options for communication between learners and tutors. Learner mobile app With our customized mobile app for Android and iOS, learners can access content anytime, ensuring they never miss an opportunity to stay on track. All you need, is EdzLMS EdzLMS’s built in features help you to get started immediately. Still if you have a custom ask, do let us know; our team can built it for you and deliver. For more, see the EdzLMS product overview. Why wait? Get your EdzLMS now. Book a Demo Edzlearn Services Private limited is at the forefront of delivering innovative LMS solutions, tailored for various industries and educatio ...
# ----------------------------------------------------------------------------------------------------
# Document 2:
#
# Skip to content Free Trial Menu Edzlms Features Summary In today’s rapidly evolving educational landscape, EDZ Learn emerges as a cutting-edge end-to-end learning platform aimed at catalyzing learner development. Built on the pillars of innovation, personalization, and accessibility, EDZ Learn is committed to transforming the way individuals engage with education. Whether you’re a student, a professional seeking skill enhancement, or an organization aiming to upskill your workforce, EDZ Learn provides the all-in-one solution. AI/ML Powered Course Courses with AR/VR SCORM Compliant LMS Competency Mapping Learning Path Interactive Platform Learning Modes Mentoring Course Management Robust User Management Gamification Mobile App Meeting Task Cohorts Reporting Cloud Hosting & White Label Solution Edit Content Edit Content Edit Content Edit Content Edit Content Edit Content Edit Content Edit Content Edit Content Edit Content Edit Content Edit Content Edit Content Edit Content Edit Content Edit Content Edit Content AI/ML Powered Course Courses with AR/VR SCORM Compliant LMS Competency Mapping Learning Path Interactive Platform Learning Modes Mentoring Course Management Robust User Management Gamification Mobile App Meeting Task Cohorts Reporting Cloud Hosting & White Label Solution See these features in action Book a Demo Edzlearn Services Private limited is at the forefront of delivering innovative LMS solutions, tailored for various industries and educational institutions worldwide. We specialize in empowering organizations to develop captivating and interactive learning experiences that resonate with learners. Quick Links Home About Us Customer Experience Plan Security Blogs Case Study Contact Terms of Use Features Detailed Feature List AI Based Learning Course Content Creation Training Delivery Methodologies Gamification And Learner Engagement Super Fast Management Of Users Multiple Environment Portal Reporting And Tracking Integration Use case University Sales Training Continuous Learning For Employee Train Your Customers Insurance Sectors Monetise Content With eCommerce Extended Training Portal Healthcare Other Industry © Copyright 2024, All Rights Reserved by EdzLearn. Take a minute Sign Up For Free Trial OR
# ----------------------------------------------------------------------------------------------------
# Document 3:
#
# Skip to content Free Trial Menu WE ARE EdzLMS Power to your learners using our collaborative learning platform Online E Learning platform : EdzLMS is at the forefront of delivering innovative LMS solutions, tailored for various industries and educational institutions worldwide.We specialize in empowering organizations to develop captivating and interactive learning experiences that resonate with learners Our Features Our story At EdzLMS , we’re on a mission to revolutionize online learning. Since day one, we have focused on innovation and research on emerging technologies in education. We are also part of the European Union’s educational research team since last 5 years, and have already published more than 4 research papers in international conferences. These papers are appreciated by more than 24 universities in Europe. WORLDWIDE Meet the Team EdzLMS At EdzLMS, our strength lies in our team of dedicated professionals who are passionate about transforming the way learning is delivered and experienced. Our diverse team combines expertise, innovation, and a commitment to excellence to create a platform that meets the unique needs of educational institutions and businesses alike. Premal Desai Premal Desai is a highly experienced professional with over 25+ years of expertise in Pre-Sales, Delivery, Service Management, and On-site/Off-Shore Engagement. He has extensive experience in Database Design, Technical Requirements Gathering, Business Requirements, and has held the position of AVP-PRE-SALES at Datamatics, with 2 experiences in that role and 3 experiences at Datamatics overall. Facebook-f Twitter Google-plus-g Mihir Jana Our visionary leader Mihir, brings over 28 years of experience in the education technology sector. With a clear mission to revolutionize learning, Mihir has been the driving force behind our growth and success. Facebook-f Twitter Google-plus-g Ratnesh Sinha Ratnesh Sinha is a passionate technology enthusiast with a proven track record in software development, delivery, and team management. With a strong background in Telecommunications, Customer Service Delivery/Management, and Mobile & Web products, Ratnesh has successfully led innovative projects for various clients across different industries. Facebook-f Twitter Google-plus-g Our Commitment At EdzLMS, we believe in the power of teamwork. Each member of our team plays a crucial role in our mission to provide a world-class learning management system. Together, we are committed to innovation, excellence, and the success of our clients. Join us on this exciting journey and discover how our dedicated team can help you transform your learning experience. EdzLMS, you are not just getting a platform; you are gaining a partner committed to your growth and success. Meet our customers Join the Collaborative Learning Movement with EdzLMS At EdzLMS, we are dedicated to transforming the landscape of education and corporate training through the power of collaboration. Our innovative LMS is designed to meet the unique needs of universities and businesses, driving measurable success and fostering a culture of continuous learning. WE ARE HIRING If you're looking to make an impact, we're looking for you Join our friendly, supportive team. We strive to find the most innovative solution, not the easy one Do you want to showcase your talent in uncharted territory? Is customer your priority? then join us More power to you with our EdzLMS Book a Demo Edzlearn Services Private limited is at the forefront of delivering innovative LMS solutions, tailored for various industries and educational institutions worldwide. We specialize in empowering organizations to develop captivating and interactive learning experiences that resonate with learners. Quick Links Home About Us Customer Experience Plan Security Blogs Case Study Contact Terms of Use Features Detailed Feature List AI Based Learning Course Content Creation Training Delivery Methodologies Gamification And Learner Engagement Su ...
# ----------------------------------------------------------------------------------------------------
# Document 4:
#
# Skip to content Free Trial Menu MANAGE USERS Effortless User Management with EdzLMS Managing users efficiently is a crucial aspect of any Learning Management System (LMS), and EdzLMS excels in providing robust and versatile user management features. With our platform, administrators can easily handle user onboarding, management, and updates through various intuitive methods. Let EdzLMS makes you more productive By leveraging these powerful user management features, EdzLMS ensures that administrators can efficiently handle all aspects of user onboarding, maintenance, and engagement, leading to a more organized and productive learning environment. Many ways to add users Bulk upload EdzLMS allows administrators to add thousands of users simultaneously by uploading a simple spreadsheet. All that's required is an email address for each user. This bulk upload feature streamlines the onboarding process, saving time and reducing administrative workload, making it ideal for large organizations or educational institutions with extensive user bases. Automation of user onboarding EdzLMS can connect with your HRIS or CRM systems to auto-import users. This integration ensures that any new user added to your HRIS or student directory, LDAP is automatically created in the LMS. This background synchronization eliminates the need for manual updates, ensuring that your LMS user base is always current and reflective of your organization's HR records. Manual registrations EdzLMS provides a manual creation option. Administrators can create individual user accounts on-the-fly, offering flexibility for unique situations such as guest access or temporary employees User self-registration EdzLMS supports user self-registration, allowing you to tailor the registration process to your organization's needs. This feature can be configured to be as open or restricted as desired. For instance, companies can enable public self-sign-up for training courses, making it convenient for users to register themselves, or restrict access to specific domains or invite-only scenarios to maintain control over who joins the LMS. Integration with third-party user directory If you use an employee directory like LDAP, Shibboleth, or Microsoft Azure, you can integrate it seamlessly to eliminate manual management. Additionally, social logins such as “Login with Facebook,” “Login with Google,” and “Login with LinkedIn” are also supported for easy access. Cohorts and group users Our EdzLMS simplifies the process of organizing users into groups based on departments, teams, or learning needs. Administrators can create and manage groups, assign courses, and track progress at a group level. This feature is particularly useful for delivering targeted training and managing large-scale learning initiatives. AIMA uses cohorts and groups to organize their learners by business, product, and role. Provide more personalized content, more rewards, and more attention to your specific group of learners Read More Customizable User Roles and Permissions Create customized roles with certain permission based on your need. You can create as many as you need and then utilize those roles to bring in more efficiency into the system Administrator Super admins have full control, managing everything from users and courses to roles and settings. EdzLMS empowers them with intuitive tools to efficiently oversee and optimize the learning environment. Instructor/Tutor Instructors manage their own courses, upload content, create quizzes, engage with learners, and grade assessments. EdzLMS provides a seamless platform for them to enhance student engagement and streamline course management. Manager Managers assist in delegating tasks, and overseeing specific courses or categories for better control. EdzLMS helps managers by offering detailed analytics and reporting tools to track progress and ensure smooth operation. Learner Learners are at the heart of EdzLMS. They can access courses and content, and track their ...
# ----------------------------------------------------------------------------------------------------
# Document 5:
#
# Skip to content Free Trial Menu CONTENT CREATION No barriers to the type of course content Create content with various formats such as scorm, interactive video, pdf files, quizzes, assignments, surveys, feedback, forums, live classes, and many more. Give your content creation a boost. Create LMS Many formats Bite-size videos, SCORM, documents, live classes, question banks, chat, forum, instructor-led blended learning… there is no end. Utilize EdzLMS to its full potential and incorporate programmed learning for a more structured approach. Create a blended learning program that mixes and matches content types seamlessly. Mix and match content types SCORM and xAPI content Upload scorm package and let your learners enjoy the voice-over, captions, and quizzes inside one package. As a tutor, you can track every bit of interaction. Videos to any course Upload videos or embed from any platform such as YouTube, Vimeo, etc. You can stop skip forward, track the percentage of progress, learning time based on your preference. Upload any files Upload and embed any files, documents, or images or you can embed also from any repository such as Google Drive, Amazon S3, dropbox, or Box Net everything is integrated in one place. Schedule Live classes Using our third-party integration of Zoom, Google Meet, Microsoft Team, Click Meeting, etc you can schedule LIVE classes, and webinars and send notifications, and reminders easily. Later use those recorded lectures inside LMS. Single course or learning program, EdzLMS has it all Sometimes just the single course is not enough, build custom learning program/path combining multiple courses so that learner can follow the guided path. Once they complete one course, let them move to the next, everything is customizable the way you need. We use EdzLMS for our teacher’s training and it is working very nice with easy navigation and detailed reports. Discover, Engage and Excel with Interactive SCORM LMS Trusted by Hundreds of Companies Worldwide… Deliver SCORM Courses with EdzLMS Easy upload of packages Just upload your zip files from any authoring tool, and with a few clicks, you're ready to start training. EdzLMS supports SCORM 1.2, ensuring smooth integration of your SCORM-based content. Completion Create a learning flow using scorm's completion tracking such as once learner completes the first scorm, they can move to second one and so on. And at end provide them the certificates to download. Easy modifications If you would like to bring in a new version of the scorm, there is no need to create new course, just edit the activity and replace the new version package. An automatic notification to the learner will be sent. Effective SCORM Reporting Check with detailed SCORM reports, offering valuable insights into your learners’ progress and training effectiveness. These reports help you understand each learner’s status, time spent on SCORM units, and their scores. Explore our most popular features EdzLMS is carefully built with the features you need to deliver the best experience for your team and your learners. See the EdzLMS platform in action. Detailed Feature List Course Content Creation Training Delivery Methodologies Gamification and Learner Engagement Super Fast Management Of Users Multiple Environment Portal Reporting and Tracking Integration Note taking and annotation Using EdzLMS features learners and tutors both can take notes, highlight inside documents, and put comments. Those comments and queries can be reviewed by the tutor and guide the learner to better learning. For more, see the EdzLMS product overview. Plagiarism checking Using an integrated plagiarism checker, tutors can easily find out how the assignments or answers given by learners are fairing. Is it copied from the internet or journals or even from other learner’s submissions? All in one place. QUESTIONS AND QUIZZES Various types of questions MCQ, T/F, Mix and math, sequence matching, mathematical calculation, equations, essay type, sh ...
# ----------------------------------------------------------------------------------------------------
# Document 6:
#
# Skip to content Free Trial Menu LMS for universities and educational institutes Are you seeking to elevate the learning and development experience within your educational institution? Are you looking to provide students with a centralized platform where they can access learning resources, track progress, and collaborate effectively? If so, you need a Learning Management System (LMS). Book A Demo Trusted by more than 400 global clients EdzLMS for Educational Institutions Benefits of Using EdzLMS: The Best LMS for University Success EdzLMS is specialized software designed to help educational institutions create, manage, and deliver eLearning content and training programs to students. As online learning continues to grow, leading LMS platforms like EdzLMS have gained global recognition. A top-notch LMS simplifies teaching and learning, fosters collaboration, and builds engaging learning environments. Contact Us Enhanced Accessibility and Flexibility LMS ensures that learning can fit around their schedules, accommodating diverse commitments such as part-time jobs, internships, and personal responsibilities. This accessibility is especially beneficial for non-traditional students, including those with family obligations or those living in remote areas, as it eliminates barriers to education and promotes a more inclusive learning environment. Personalized Learning Paths Students experience personalized learning tailored to their individual needs and preferences. The platform allows for customization of learning paths based on students' strengths, weaknesses, and interests. Adaptive learning technologies within EdzLMS can suggest additional resources, provide targeted feedback, and adjust the difficulty of tasks, ensuring that each student receives an education that is as unique as they are. Collaborative Learning Opportunities Collaboration is a cornerstone of EdzLMS, which offers numerous tools for peer-to-peer and student-to-teacher interaction. Features like group projects, discussion boards, and real-time chat facilitate collaboration, enabling students to work together, share insights, and support each other’s learning. SCALE From local to foreign students Take your blended and online courses to the world. Using EdzLMS you can attract talents across the world to join your course and provide world class education Blended learning at it's best Utilize tools like live classes, video feedback, and audio feedback to deliver a blended learning experience that will be appreciated by students worldwide. SCALE Cost-Effective Learning Solutions Using EdzLMS can significantly reduce the costs associated with traditional learning. By offering digital resources and online courses, EdzLMS eliminates the need for physical textbooks and materials, which can be expensive. Interactive and Engaging Learning Environment EdzLMS integrates interactive elements such as quizzes, discussion forums, and multimedia resources to create an engaging learning environment. This interactive approach helps maintain student interest and encourages active participation. Gamification features, like leaderboards and badges, add a competitive edge that can motivate students to stay engaged and perform better. The use of multimedia resources, including videos and simulations, caters to various learning styles, making complex concepts easier to understand and retain. This dynamic learning environment helps to foster a deeper connection to the material and promotes a more enriching educational experience. CREDIT AND CERTIFY Comprehensive Progress Tracking EdzLMS provides robust tracking and analytics tools that allow students to monitor their progress and performance in real-time. With features like detailed gradebooks, progress dashboards, and performance analytics, students can easily identify their strengths and areas for improvement. This transparency helps students stay on track and take proactive steps to address any academic challenges. Regular feedback and prog ...

# %%
# Define the prompt
prompt = """
You are an AI-powered virtual assistant, your name is 'EdzLms', designed by EdzLearn Service Private Limited.
Your task is to help the students with their study purposes.
Use the following pieces of context to answer the question at the end and you can also answer the question based on your knowledge.
If you don't know the answer, just say that 'I don't have enough information to answer this question'.

Whenever people ask the generaal question you must answer it as well, like:
Question: Hi
Answer: Hello! How can I assist you with your studies today?

Question: What is your name?
Answer: I am EdzLms, your virtual assistant designed by EdzLearn Service Private Limited.

Context: `{context}`
Question: `{question}`
"""

prompt_template = PromptTemplate(
    template=prompt,
    input_variables=['context', 'question']
)

llm_chain2 = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=compression_retriever,
    chain_type_kwargs={"prompt": prompt_template}
)

# %%
import re
from IPython.display import display, Markdown

def extract_first_answer(query: str) -> str:
    response = llm_chain2.invoke(query)
    response = response['result']
    pattern = r"Answer:\s*`([^`]+)`"

    match_ = re.search(pattern, response)

    if match_:
        return display(Markdown(match_.group(1).strip()))
    else:
        return "No answer found."

# %%
extract_first_answer(query="What is EdzLms?")
# Out:
# NO_OUTPUT

# %%
extract_first_answer(query="What are features you provide?")
# Out:
# I don't have enough information to answer this question. The context does not provide any information about the features provided by EdzLMS.

# %%
# https://github.com/sunnysavita10/Generative-AI-Indepth-Basic-to-Advance/blob/main/basic_retrieval_and_contextual_compression_retrieval.ipynb
