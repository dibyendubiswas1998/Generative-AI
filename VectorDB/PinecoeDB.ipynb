# %% [markdown]
# # **Pinecone DB:**

# %%
# !pip install langchain
# !pip install sentence-transformers==2.2.2
# !pip install pinecone-client==2.2.4
# !pip install pypdf
# !pip install langchain_google_genai

# %%
import os

ROOT = "/content/drive/MyDrive/Generative AI/Vector Database"
os.chdir(ROOT)

# %% [markdown]
# ## **Load Data Sets:**
#
# * Get the data
# * Unzip the data

# %%
from langchain.document_loaders import PyPDFDirectoryLoader
loader = PyPDFDirectoryLoader("pdf_data")
data = loader.load()
data
# Out:
# [Document(page_content='Profile\nA results-driven BCA graduate with a passion for leveraging advanced data science techniques to extract valuable insights\nfrom complex datasets, my expertise lies in the strategic application of statistical methods, machine learning, deep learning,\nNLP, computer vision, and state-of-the-art tools. I possess the ability to perform in-depth data analysis and manipulation\nand can develop full-stack data science projects. Currently, I am expanding my knowledge in MLOps and Generative\nAI.\nSkills\nPython|Excel|Power BI|SQL|Rest-API (Flask)|Operating System (Windows | Ubuntu)|Statistics\nMachine Learning (Scikit-learn)|Deep Learning (PyTorch | TensorFlow)\nComputer Vision (Convolutional Neural Network | Image processing | Object Classification)\nNatural Language Processing (Classification | Summarization | Generation | Name Entity Recognition | RNN | LSTM |\nGRU | Transformers | GPT)\nGit|GitHub|ML-Ops (DVC | MLFlow | Docker | Kubernetes | CI-CD (GitHub Actions))|Cloud (AWS)\nProfessional Experience\nData Scientist Intern, ineuron.ai Sep\xa02023 – Dec\xa02023 | Bangalore, India\nTech Stack: Python, PyTorch, S3, EC2, ECR, Git, CI/CD (GitHub Actions), DVC, MLflow, Docker.\n•Engineered a highly efficient Document-Tagging system utilizing state-of-the-art models from Hugging Face; achieved a \n50% increase in accuracy and reduced manual categorization time by 70%, enhancing data organization and decision-\nmaking processes.\n•Spearheaded the implementation of transformer-based models, resulting in a 35% decrease in document categorization \ntime and a 20% improvement in accuracy after fine-tuning for increased efficiency.\n•Employed S3 buckets to enhance data management efficiency.\n•Containerized the project for seamless deployment and reproducibility, hosted on Docker Hub for accessibility.\n•Established a resilient CI/CD pipeline via GitHub Actions, automating end-to-end processes including Data \nCollection, Preprocessing, Model Training, Evaluation, and Deployment.\n•Implemented AWS hosting for the system, ensuring scalability, and optimizing storage and retrieval efficiency.\nProjects\nNews Short, Text Summarization Web App Jun\xa02023 – Aug\xa02023\nTech Stack: Python, PyTorch, S3, EC2, ECR, Git, CI/CD (GitHub Actions), DVC, MLflow, Docker.\n•Developed a Text Summarization Web App with CI/CD integration, automating Data Collection, Preprocessing, \nModel Training, and Prediction, resulting in a 40% reduction in development time and increased efficiency.\n•Employed a Fine-Tuning approach in the development process, contributing to the creation of an intuitive web interface \nfor the Text Summarization App, which led to a 25% improvement in user engagement and overall satisfaction.\n•Implemented adjustable parameters, empowering users to customize summarization lengths.\n•Provided real-time updates on local and global events during the summarization process, enhancing user engagement by \n20% and delivering more dynamic content summaries.\n•Dockerized the entire project for streamlined deployment and reproducibility, resulting in a 50% reduction in \ndeployment time and increased collaboration efficiency.\n•Deployed the Text Summarization App on AWS, achieving 99.9% uptime, ensuring scalability, and delivering reliable \nperformance for users, contributing to a 15% improvement in overall user experience.Dibyendu Biswas\nData Scientist\ndibyendubiswas1998@gmail.com 9907278562 Siliguri, West Bengal\nhttps://github.com/dibyendubiswas1998 https://www.linkedin.com/in/dibyendubiswas1998\ndibyendubiswas1998@gmail.com 1 / 2', metadata={'source': 'pdf_data/Dibyendu-Biswas-Resume.pdf', 'page': 0}),
#  Document(page_content="Insurance Premium Prediction, ML App Apr\xa02023 – Jun\xa02023\nTech Stack: Python, Scikit-learn, S3, EC2, ECR, Git, CI/CD (GitHub Actions), DVC, MLflow, Docker.\n•Engineered precise Insurance Premium Predictions using diverse machine learning models in Python with Scikit-\nlearn, achieving a significant 95% improvement in accuracy.\n•Empowered customers in plan selection by providing accurate estimates, and emphasizing health aspects over financial \nconsiderations.\n•Conducted a comparative analysis of machine learning models, resulting in a trustworthy 95% improvement in \npremium prediction accuracy.\n•Implemented enhancements for a reliable 95% improvement in premium prediction accuracy, ensuring trustworthy \nestimates for users.\n•Utilized S3 bucket for efficient data management, optimizing the storage and retrieval processes.\n•Containerized the application for seamless deployment and reproducibility. Established a robust CI/CD pipeline with \nGit, GitHub Actions, and DVC for automated expense estimate generation. Tracked experiments in DagsHub using \nMLflow for comprehensive documentation. Deployed on AWS for scalability and dependable performance.\nSupply Chain Insights in FMCG Domain Mar\xa02023 – Apr\xa02023\nTech Stack: Excel, Power BI, Microsoft PowerPoint.\n•Constructed a comprehensive Power BI dashboard focused on key performance indicators (KPIs) such as on-time \ndelivery (OT), in-full delivery (IF), and on-time in-full (OTIF) percentages, effectively tracking service levels for \nAtliQ Mart, an FMCG manufacturer.\n•The Power BI dashboard facilitated proactive service management at AtliQ Mart, enabling the identification and \nresolution of key customer issues before business expansion.\n•The analysis conducted had the potential to save 20% of AtliQ Mart's investment in expansion by addressing critical \nissues highlighted in the dashboard.\n•Developed a final report summarizing supply chain insights and their potential impact, shared with stakeholders.\n•Utilized Excel for data analysis and Microsoft PowerPoint for the creation and presentation of the final report.\n•Contributed to enhanced decision-making processes by providing actionable insights through the Power BI dashboard.\nRevenue Insights in Hospitality Domain Jan\xa02023 – Feb\xa02023\nTech Stack: Excel, Power BI, Microsoft PowerPoint.\n•Conducted a detailed analysis for Atliq Grands to identify the root causes of declining market share and revenue.\n•Developed a Power BI dashboard using three months of data, offering a comprehensive view of revenue trends for \nAtliq Grands.\n•Utilized the Power BI dashboard to provide valuable insights to the Revenue team, enabling strategic actions for \nregaining lost revenue and market share.\n•Insights gathered from the dashboard aimed at contributing to a significant recovery, projecting a goal of increasing \nrevenue and market share by 20% in the next month.\n•Created a final report summarizing revenue insights and proposed strategies, sharing it with stakeholders.\n•Employed Excel for data analysis and Microsoft PowerPoint for the creation and presentation of the final report.\nEducation\nBCA, IGNOU 2023 | Siliguri, India\nPersonal Information\n•Date of Birth: 12-Mar-1999.\n•Father’s Name: Tapan Kumar Biswas.\n•Nationality: Indian.\n•Marital Status: Single.\n•Languages: English, Bengali, and Hindi.\n•Hobbies: listening to music, and Travelling.\ndibyendubiswas1998@gmail.com 2 / 2", metadata={'source': 'pdf_data/Dibyendu-Biswas-Resume.pdf', 'page': 1})]

# %% [markdown]
# ## **Data Chunking:**

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=70, chunk_overlap=20)
texts_chunks = text_splitter.split_documents(data)

# %%
texts_chunks[2]
# Out:
# Document(page_content='leveraging advanced data science techniques to extract valuable', metadata={'source': 'pdf_data/Dibyendu-Biswas-Resume.pdf', 'page': 0})

# %%
# number of documents after data chunking:

len(texts_chunks)
# Out:
# 144

# %% [markdown]
# ## **Embeddings:**

# %%
from langchain.embeddings import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %%
query_result = embeddings.embed_query("Hello World")
print(len(query_result))
# Out:
# 384

# %% [markdown]
# ## **Create a Vector DB (Pinecone):**

# %% [markdown]
# ### **Access the Pinecone key**

# %%
PINECONE_API_KEY = os.environ.get('PINECONE_API_KEY', 'b7be3679-39fd-4701-bbfc-777a605aa412')
PINECONE_API_ENV = os.environ.get('PINECONE_API_ENV', 'gcp-starter')

# %%
import pinecone
# initialize pinecone
pinecone.init(
    api_key=PINECONE_API_KEY,  # find at app.pinecone.io
    environment=PINECONE_API_ENV  # next to api key in console
)
index_name = "test" # put in the name of your pinecone index here

# %% [markdown]
# ### **Store the Embedding vector to Pinecone DB:**

# %%
from langchain.vectorstores import Pinecone

docsearch = Pinecone.from_texts([t.page_content for t in texts_chunks], embeddings, index_name=index_name)

# %% [markdown]
# ### **If you already have an index, you can load it like this:**

# %%
docsearch = Pinecone.from_existing_index(index_name, embeddings)
docsearch

# %% [markdown]
# ## **Perform Sementic Search:**

# %%
query = "Tell me something about Dibyendu Biswas?"
docs = docsearch.similarity_search(query, k=100) # retrive top 100 relevent or similar documents
docs
# Out:
# [Document(page_content='in overall user experience.Dibyendu Biswas'),
#  Document(page_content='•Date of Birth: 12-Mar-1999.\n•Father’s Name: Tapan Kumar Biswas.'),
#  Document(page_content='dibyendubiswas1998@gmail.com 1 / 2'),
#  Document(page_content='dibyendubiswas1998@gmail.com 2 / 2'),
#  Document(page_content='dibyendubiswas1998@gmail.com 9907278562 Siliguri, West Bengal'),
#  Document(page_content='https://github.com/dibyendubiswas1998'),
#  Document(page_content='Education\nBCA, IGNOU 2023 | Siliguri, India\nPersonal Information'),
#  Document(page_content='Data Scientist Intern, ineuron.ai Sep\xa02023 – Dec\xa02023 | Bangalore,'),
#  Document(page_content='•Nationality: Indian.\n•Marital Status: Single.'),
#  Document(page_content='https://www.linkedin.com/in/dibyendubiswas1998'),
#  Document(page_content='•Languages: English, Bengali, and Hindi.'),
#  Document(page_content='Data Scientist'),
#  Document(page_content='to extract valuable insights'),
#  Document(page_content='Projects\nNews Short, Text Summarization Web App Jun\xa02023 – Aug\xa02023'),
#  Document(page_content='application of statistical methods, machine learning, deep learning,'),
#  Document(page_content='a goal of increasing'),
#  Document(page_content='considerations.'),
#  Document(page_content='user engagement by'),
#  Document(page_content='I possess the ability to perform in-depth data analysis and'),
#  Document(page_content='| Bangalore, India'),
#  Document(page_content='contributing to a significant recovery, projecting a goal of'),
#  Document(page_content='20% and delivering more dynamic content summaries.'),
#  Document(page_content='Face; achieved a'),
#  Document(page_content='data analysis and manipulation'),
#  Document(page_content='Profile'),
#  Document(page_content='Collection, Preprocessing, Model Training, Evaluation, and'),
#  Document(page_content='•Contributed to enhanced decision-making processes by providing'),
#  Document(page_content='providing accurate estimates, and emphasizing health aspects over'),
#  Document(page_content='health aspects over financial'),
#  Document(page_content='•Hobbies: listening to music, and Travelling.'),
#  Document(page_content='of data, offering a comprehensive view of revenue trends for'),
#  Document(page_content='leveraging advanced data science techniques to extract valuable'),
#  Document(page_content='| Summarization | Generation | Name Entity Recognition | RNN | LSTM |'),
#  Document(page_content='CI/CD integration, automating Data Collection, Preprocessing,'),
#  Document(page_content='Atliq Grands.'),
#  Document(page_content='•Developed a Text Summarization Web App with CI/CD integration,'),
#  Document(page_content='A results-driven BCA graduate with a passion for leveraging advanced'),
#  Document(page_content='and can develop full-stack data science projects. Currently, I am'),
#  Document(page_content='learn, achieving a significant 95% improvement in accuracy.'),
#  Document(page_content='from complex datasets, my expertise lies in the strategic application'),
#  Document(page_content='regaining lost revenue and market share.'),
#  Document(page_content='•Utilized the Power BI dashboard to provide valuable insights to the'),
#  Document(page_content='•Developed a Power BI dashboard using three months of data, offering'),
#  Document(page_content='•Conducted a comparative analysis of machine learning models,'),
#  Document(page_content='•Containerized the application for seamless deployment and'),
#  Document(page_content='•The Power BI dashboard facilitated proactive service management at'),
#  Document(page_content='insights and their potential impact, shared with stakeholders.'),
#  Document(page_content='PowerPoint for the creation and presentation of the final report.'),
#  Document(page_content='PowerPoint for the creation and presentation of the final report.'),
#  Document(page_content='process, contributing to the creation of an intuitive web interface'),
#  Document(page_content='and proposed strategies, sharing it with stakeholders.'),
#  Document(page_content='Image processing | Object Classification)'),
#  Document(page_content="•The analysis conducted had the potential to save 20% of AtliQ Mart's"),
#  Document(page_content='Computer Vision (Convolutional Neural Network | Image processing |'),
#  Document(page_content='•Employed a Fine-Tuning approach in the development process,'),
#  Document(page_content='•Insights gathered from the dashboard aimed at contributing to a'),
#  Document(page_content='making processes.'),
#  Document(page_content='•Containerized the project for seamless deployment and'),
#  Document(page_content='•Constructed a comprehensive Power BI dashboard focused on key'),
#  Document(page_content='revenue and market share by 20% in the next month.'),
#  Document(page_content='Currently, I am expanding my knowledge in MLOps and Generative'),
#  Document(page_content='NLP, computer vision, and state-of-the-art tools. I possess the'),
#  Document(page_content='events during the summarization process, enhancing user engagement by'),
#  Document(page_content='AI.\nSkills'),
#  Document(page_content='•Dockerized the entire project for streamlined deployment and'),
#  Document(page_content='delivery (OT), in-full delivery (IF), and on-time in-full (OTIF)'),
#  Document(page_content='25% improvement in user engagement and overall satisfaction.'),
#  Document(page_content='Evaluation, and Deployment.'),
#  Document(page_content='Professional Experience'),
#  Document(page_content='Git|GitHub|ML-Ops (DVC | MLFlow | Docker | Kubernetes | CI-CD (GitHub'),
#  Document(page_content='•Empowered customers in plan selection by providing accurate'),
#  Document(page_content='by providing actionable insights through the Power BI dashboard.'),
#  Document(page_content='Machine Learning (Scikit-learn)|Deep Learning (PyTorch | TensorFlow)'),
#  Document(page_content='•Utilized Excel for data analysis and Microsoft PowerPoint for the'),
#  Document(page_content='management at AtliQ Mart, enabling the identification and'),
#  Document(page_content='estimates for users.'),
#  Document(page_content='learning models, resulting in a trustworthy 95% improvement in'),
#  Document(page_content='expense estimate generation. Tracked experiments in DagsHub using'),
#  Document(page_content='time by 70%, enhancing data organization and decision-'),
#  Document(page_content='for the Text Summarization App, which led to a 25% improvement in'),
#  Document(page_content='users to customize summarization lengths.'),
#  Document(page_content='Natural Language Processing (Classification | Summarization |'),
#  Document(page_content='performance for users, contributing to a 15% improvement in overall'),
#  Document(page_content='99.9% uptime, ensuring scalability, and delivering reliable'),
#  Document(page_content='•Employed Excel for data analysis and Microsoft PowerPoint for the'),
#  Document(page_content='•Created a final report summarizing revenue insights and proposed'),
#  Document(page_content='Git, CI/CD (GitHub Actions), DVC, MLflow, Docker.'),
#  Document(page_content='Git, CI/CD (GitHub Actions), DVC, MLflow, Docker.'),
#  Document(page_content='Git, CI/CD (GitHub Actions), DVC, MLflow, Docker.'),
#  Document(page_content='•Conducted a detailed analysis for Atliq Grands to identify the root'),
#  Document(page_content='resolution of key customer issues before business expansion.'),
#  Document(page_content='System (Windows | Ubuntu)|Statistics'),
#  Document(page_content='•Established a resilient CI/CD pipeline via GitHub Actions,'),
#  Document(page_content='•Spearheaded the implementation of transformer-based models,'),
#  Document(page_content='Revenue Insights in Hospitality Domain Jan\xa02023 – Feb\xa02023'),
#  Document(page_content='deployment and reproducibility. Established a robust CI/CD pipeline'),
#  Document(page_content='•Provided real-time updates on local and global events during the'),
#  Document(page_content='CI/CD pipeline with'),
#  Document(page_content='•Implemented AWS hosting for the system, ensuring scalability, and'),
#  Document(page_content='in-full (OTIF) percentages, effectively tracking service levels for')]

# %% [markdown]
# ## **Integration with Language Models (LLM):**

# %% [markdown]
# ### **Access the Gimini API Key Token:**

# %%
from google.colab import userdata
Gemini_API_Key = userdata.get('gimini_api_key_1') # get the Gemini API Key

# %% [markdown]
# ### **Load the Gimini LLM model:**

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-pro", google_api_key=Gemini_API_Key, convert_system_message_to_human=True) # load the gemini-pro model
llm
# Out:
# ChatGoogleGenerativeAI(model='gemini-pro', google_api_key=SecretStr('**********'), client=genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
# ), convert_system_message_to_human=True)

# %% [markdown]
# ## **Generating Answers:**

# %% [markdown]
# ### **Create a LangChain Chain for retrieve the Information:**

# %%
from langchain.chains import RetrievalQA
qa_chain = RetrievalQA.from_chain_type(llm=llm,
                                  chain_type="stuff",
                                  retriever=docsearch.as_retriever(),
                                  return_source_documents=True)

# %%
query = "Tell me something about 'Dibyendu Biswas'?" # ask question:
llm_response = qa_chain.invoke(query) # get most accurate result

print(llm_response['result'])
# Out:
# The provided text does not mention anything about 'Dibyendu Biswas' other than their name, date of birth, and father's name. So I cannot answer this question.
